# %%
import boto3
import io
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# export to S-3
import awswrangler as wr

# Imputation
from sklearn.impute import SimpleImputer


plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings("ignore")

# %%
#!pip install awswrangler

# %%
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ### Load a consolidated and expanded file from S-3

# %%
session = boto3.Session()
s3 = session.client('s3')

# %%
bucket_name = 'ppsg-collections'
file_name = '2021-06-01/consolidated/random_data/consolidated_sample_expanded.parquet'

# %%
# %%time
obj = s3.get_object(Bucket = bucket_name, Key = file_name)
df = pd.read_parquet(io.BytesIO(obj['Body'].read()))
# Out:
# CPU times: user 1min 57s, sys: 6min 10s, total: 8min 8s
# Wall time: 54.8 s

# %%
df.isnull().sum() / len(df)
# Out:
# loanid                              0.000000e+00
# loanstatusid                        0.000000e+00
# nextpaymentduedt                    0.000000e+00
# rundt                               0.000000e+00
# ndd                                 0.000000e+00
# rundatenumber                       0.000000e+00
# priormeperiod                       0.000000e+00
# MEPeriod                            0.000000e+00
# loanstatus                          0.000000e+00
# priorstatus                         5.800617e-03
# EscrowFlag                          0.000000e+00
# currentescrowpayment                0.000000e+00
# nextescrowpayment                   5.114234e-05
# currentpipayment                    0.000000e+00
# nextpipayment                       5.800617e-03
# OpenLossDraftClaimAmount            0.000000e+00
# upb                                 0.000000e+00
# priorupb                            5.800617e-03
# CurrentAmortTerm                    0.000000e+00
# LastPaymentEffectiveDate            1.535907e-02
# LastPaymentDt                       1.195133e-02
# nextLastPaymentDt                   8.901437e-04
# LastPaymentAmt                      0.000000e+00
# LoanModificationDt                  9.366215e-01
# ForebearanceStatusCodeId            9.326278e-01
# InvestorId                          0.000000e+00
# DraftingIndicator                   7.868188e-01
# DraftLastScheduledDt                8.266488e-01
# draftday                            8.266488e-01
# InvestorName                        0.000000e+00
# status24months                      5.800617e-03
# monthssincecurrent                  5.800617e-03
# monthssince30                       5.800617e-03
# monthssince60                       5.800617e-03
# monthssince90                       5.800617e-03
# monthssince120                      5.800617e-03
# monthssinceFC                       5.800617e-03
# monthssinceBK                       5.800617e-03
# prior24historyCurrent               5.800617e-03
# prior24history30D                   5.800617e-03
# prior24history60D                   5.800617e-03
# prior24history90D                   5.800617e-03
# prior24history120D                  5.800617e-03
# prior24historyFC                    5.800617e-03
# prior12historyCurrent               5.800617e-03
# prior12history30D                   5.800617e-03
# prior12history60D                   5.800617e-03
# prior12history90D                   5.800617e-03
# prior12history120D                  5.800617e-03
# prior12historyFC                    5.800617e-03
# prior6historyCurrent                5.800617e-03
# prior6history30D                    5.800617e-03
# prior6history60D                    5.800617e-03
# prior6history90D                    5.800617e-03
# prior6history120D                   5.800617e-03
# prior6historyFC                     5.800617e-03
# CampaignProfile                     2.995480e-04
# RiskScore                           3.868102e-01
# samemailingandpropertyaddress       1.692580e-03
# samemailingandpropertyzip           1.692615e-03
# reversalcount_3months               0.000000e+00
# reversalcount_6months               0.000000e+00
# reversalcount_12months              0.000000e+00
# reversalamt_3months                 0.000000e+00
# reversalamt_6months                 0.000000e+00
# reversalamt_12months                0.000000e+00
# nsfcount_3months                    0.000000e+00
# nsfcount_6months                    0.000000e+00
# nsfcount_12months                   0.000000e+00
# nsfamt_3months                      0.000000e+00
# nsfamt_6months                      0.000000e+00
# nsfamt_12months                     0.000000e+00
# bph_3months                         0.000000e+00
# bph_6months                         0.000000e+00
# bph_12months                        0.000000e+00
# bph_24months                        0.000000e+00
# mostrecentprokenpromisehistory      9.165624e-01
# rpc_3months                         0.000000e+00
# rpc_6months                         0.000000e+00
# rpc_12months                        0.000000e+00
# rpc_24months                        0.000000e+00
# mostrecentcontact                   4.064649e-01
# curtailment_3months                 0.000000e+00
# curtailment_6months                 0.000000e+00
# curtailment_12months                0.000000e+00
# COVIDforbearancetype                9.473662e-01
# CA_Value                            3.002840e-01
# CA_ConfScore                        3.002840e-01
# Trendix_Value                       2.458462e-01
# Leadgen_Value                       2.111889e-01
# RunPeriod                           2.111889e-01
# rollingsixmonthavg                  2.111889e-01
# AvgPmtDay_3M                        7.025047e-08
# AvgPmtDay_6M                        7.025047e-08
# AvgPmtDay_12M                       7.025047e-08
# Dlq_Count_12M                       7.025047e-08
# CurPmtNotMade                       7.025047e-08
# ACHPmtSet                           7.025047e-08
# PaymentInFullStopCode               7.025047e-08
# acquisitiondt                       2.667762e-03
# producttype                         0.000000e+00
# FICOScore                           0.000000e+00
# PurchaseDt                          0.000000e+00
# selfemployed                        2.584667e-01
# BackDTI                             3.321507e-01
# FrontDTI                            0.000000e+00
# TotalIncome                         2.408895e-01
# DUtype                              2.407515e-01
# LTV                                 0.000000e+00
# CLTV                                2.407537e-01
# RealEstateOwnedCount                0.000000e+00
# LoanPurpose                         0.000000e+00
# borrowercount                       0.000000e+00
# fsttimehomebuyer                    3.664904e-02
# amortizationtype                    0.000000e+00
# doctype                             2.407515e-01
# PropState                           0.000000e+00
# zipcode                             0.000000e+00
# CBSACode                            0.000000e+00
# PropertyType                        4.250153e-06
# Units                               4.766494e-05
# Occupancy                           0.000000e+00
# FirstDueDt                          0.000000e+00
# channel                             0.000000e+00
# HighBalanaceFlag                    1.489310e-05
# origterm                            2.825931e-03
# origbal                             0.000000e+00
# origrate                            0.000000e+00
# NoteDt                              0.000000e+00
# origpropvalue                       0.000000e+00
# Entity                              0.000000e+00
# tract_income_category               4.342795e-01
# application_income_category         4.342802e-01
# EMPL_Income                         0.000000e+00
# OTHR_Income                         0.000000e+00
# PNSN_Income                         0.000000e+00
# RNTL_Income                         0.000000e+00
# SEMP_Income                         0.000000e+00
# SSEC_Income                         0.000000e+00
# TI                                  0.000000e+00
# purperiod                           0.000000e+00
# HomeReadyHomePossibleFlag           0.000000e+00
# streamlineflag                      0.000000e+00
# apprbucket                          0.000000e+00
# amorttype                           0.000000e+00
# termbucket                          0.000000e+00
# CRAFlag                             0.000000e+00
# rollback                            0.000000e+00
# PastDue                             0.000000e+00
# days_in_month                       0.000000e+00
# PmtDt                               0.000000e+00
# PaidDt                              0.000000e+00
# Down2                               0.000000e+00
# rundt_day                           0.000000e+00
# rundt_weekday                       0.000000e+00
# nextpaymentdue_day                  0.000000e+00
# nextpayment_weekday                 0.000000e+00
# age                                 0.000000e+00
# FICO_200                            0.000000e+00
# FICO_flag                           0.000000e+00
# EMPL_Income_per                     3.723275e-06
# OTHR_Income_per                     3.723275e-06
# PNSN_Income_per                     3.723275e-06
# RNTL_Income_per                     3.723275e-06
# SEMP_Income_per                     3.723275e-06
# SSEC_Income_per                     3.723275e-06
# current_total_pmt                   0.000000e+00
# upb_change                          5.800617e-03
# forebearance_status_flag            0.000000e+00
# drafting_ind_flag                   0.000000e+00
# Covid_flag                          0.000000e+00
# selfemployed_flag                   0.000000e+00
# DUtype_flag                         0.000000e+00
# doctype_flag                        0.000000e+00
# tract_income_category_flag          0.000000e+00
# application_income_category_flag    0.000000e+00
# mod_flag                            0.000000e+00
# draft_flag                          0.000000e+00
# ACHPmtSet_flag                      0.000000e+00
# loanstatusid_lag1                   3.512524e-08
# lag1_PI                             3.512524e-08
# lag1_Escrow                         3.512524e-08
# lag1_total_pmt                      3.512524e-08
# TI_change                           3.512524e-08
# PI_change                           3.512524e-08
# Escrow_change                       3.512524e-08
# AvgPmtDay_3M_bucket                 0.000000e+00
# AvgPmtDay_6M_bucket                 0.000000e+00
# AvgPmtDay_12M_bucket                0.000000e+00
# streamline_flag                     0.000000e+00
# dtype: float64

# %%
upb1=df[df['upb'].isnull()]

# %%
df.dtypes
# Out:
# loanid                                       int64
# loanstatusid                                object
# nextpaymentduedt                    datetime64[ns]
# rundt                               datetime64[ns]
# ndd                                        float64
# rundatenumber                              float64
# priormeperiod                              float64
# MEPeriod                                   float64
# loanstatus                                  object
# priorstatus                                 object
# EscrowFlag                                  object
# currentescrowpayment                       float64
# nextescrowpayment                          float64
# currentpipayment                           float64
# nextpipayment                              float64
# OpenLossDraftClaimAmount                   float64
# upb                                        float64
# priorupb                                   float64
# CurrentAmortTerm                           float64
# LastPaymentEffectiveDate            datetime64[ns]
# LastPaymentDt                       datetime64[ns]
# nextLastPaymentDt                   datetime64[ns]
# LastPaymentAmt                             float64
# LoanModificationDt                  datetime64[ns]
# ForebearanceStatusCodeId                    object
# InvestorId                                  object
# DraftingIndicator                           object
# DraftLastScheduledDt                datetime64[ns]
# draftday                                   float64
# InvestorName                                object
# status24months                              object
# monthssincecurrent                         float64
# monthssince30                              float64
# monthssince60                              float64
# monthssince90                              float64
# monthssince120                             float64
# monthssinceFC                              float64
# monthssinceBK                              float64
# prior24historyCurrent                      float64
# prior24history30D                          float64
# prior24history60D                          float64
# prior24history90D                          float64
# prior24history120D                         float64
# prior24historyFC                           float64
# prior12historyCurrent                      float64
# prior12history30D                          float64
# prior12history60D                          float64
# prior12history90D                          float64
# prior12history120D                         float64
# prior12historyFC                           float64
# prior6historyCurrent                       float64
# prior6history30D                           float64
# prior6history60D                           float64
# prior6history90D                           float64
# prior6history120D                          float64
# prior6historyFC                            float64
# CampaignProfile                             object
# RiskScore                                  float64
# samemailingandpropertyaddress              float64
# samemailingandpropertyzip                  float64
# reversalcount_3months                      float64
# reversalcount_6months                      float64
# reversalcount_12months                     float64
# reversalamt_3months                        float64
# reversalamt_6months                        float64
# reversalamt_12months                       float64
# nsfcount_3months                           float64
# nsfcount_6months                           float64
# nsfcount_12months                          float64
# nsfamt_3months                             float64
# nsfamt_6months                             float64
# nsfamt_12months                            float64
# bph_3months                                float64
# bph_6months                                float64
# bph_12months                               float64
# bph_24months                               float64
# mostrecentprokenpromisehistory      datetime64[ns]
# rpc_3months                                float64
# rpc_6months                                float64
# rpc_12months                               float64
# rpc_24months                               float64
# mostrecentcontact                   datetime64[ns]
# curtailment_3months                        float64
# curtailment_6months                        float64
# curtailment_12months                       float64
# COVIDforbearancetype                        object
# CA_Value                                   float64
# CA_ConfScore                               float64
# Trendix_Value                              float64
# Leadgen_Value                              float64
# RunPeriod                                  float64
# rollingsixmonthavg                         float64
# AvgPmtDay_3M                               float64
# AvgPmtDay_6M                               float64
# AvgPmtDay_12M                              float64
# Dlq_Count_12M                              float64
# CurPmtNotMade                              float64
# ACHPmtSet                                  float64
# PaymentInFullStopCode                      float64
# acquisitiondt                       datetime64[ns]
# producttype                                 object
# FICOScore                                  float64
# PurchaseDt                          datetime64[ns]
# selfemployed                                object
# BackDTI                                    float64
# FrontDTI                                   float64
# TotalIncome                                float64
# DUtype                                      object
# LTV                                        float64
# CLTV                                       float64
# RealEstateOwnedCount                       float64
# LoanPurpose                                 object
# borrowercount                              float64
# fsttimehomebuyer                            object
# amortizationtype                            object
# doctype                                     object
# PropState                                   object
# zipcode                                     object
# CBSACode                                    object
# PropertyType                                object
# Units                                      float64
# Occupancy                                   object
# FirstDueDt                                 float64
# channel                                     object
# HighBalanaceFlag                            object
# origterm                                   float64
# origbal                                    float64
# origrate                                   float64
# NoteDt                              datetime64[ns]
# origpropvalue                              float64
# Entity                                      object
# tract_income_category                       object
# application_income_category                 object
# EMPL_Income                                float64
# OTHR_Income                                float64
# PNSN_Income                                float64
# RNTL_Income                                float64
# SEMP_Income                                float64
# SSEC_Income                                float64
# TI                                         float64
# purperiod                                  float64
# HomeReadyHomePossibleFlag                  float64
# streamlineflag                              object
# apprbucket                                  object
# amorttype                                   object
# termbucket                                  object
# CRAFlag                                     object
# rollback                                   float64
# PastDue                                      int64
# days_in_month                                int64
# PmtDt                               datetime64[ns]
# PaidDt                                       int64
# Down2                                        int64
# rundt_day                                    int64
# rundt_weekday                                int64
# nextpaymentdue_day                           int64
# nextpayment_weekday                          int64
# age                                          int64
# FICO_200                                     int64
# FICO_flag                                    int64
# EMPL_Income_per                            float64
# OTHR_Income_per                            float64
# PNSN_Income_per                            float64
# RNTL_Income_per                            float64
# SEMP_Income_per                            float64
# SSEC_Income_per                            float64
# current_total_pmt                          float64
# upb_change                                 float64
# forebearance_status_flag                     int64
# drafting_ind_flag                            int64
# Covid_flag                                   int64
# selfemployed_flag                            int64
# DUtype_flag                                  int64
# doctype_flag                                 int64
# tract_income_category_flag                   int64
# application_income_category_flag             int64
# mod_flag                                     int64
# draft_flag                                   int64
# ACHPmtSet_flag                               int64
# loanstatusid_lag1                           object
# lag1_PI                                    float64
# lag1_Escrow                                float64
# lag1_total_pmt                             float64
# TI_change                                  float64
# PI_change                                  float64
# Escrow_change                              float64
# AvgPmtDay_3M_bucket                         object
# AvgPmtDay_6M_bucket                         object
# AvgPmtDay_12M_bucket                        object
# streamline_flag                              int64
# dtype: object

# %%
upb1.groupby(['nextpaymentduedt'])['loanid'].count()
# Out:
# Series([], Name: loanid, dtype: int64)

# %% [markdown]
# ### Data Treatments

# %%
def avg_payment_day(col):
    conditions  = [df[col] <= 5, (df[col] >5) & (df[col] <= 10),  (df[col]>=11) ]
    choices     = [ '1_5', '6_10' , '11_30']
    df[col + '_bucket'] = np.select(conditions, choices, default='missing')

# %% [markdown]
# #### Change Data Types

# %%
# To Numeric
#num_cols = ['origbal','currentescrowpayment', 'nextescrowpayment', 'currentpipayment', 'nextpipayment', 
#        'OpenLossDraftClaimAmount','upb','priorupb'] 

#df[num_cols]  = df[num_cols].apply(pd.to_numeric)

# %%
# Datetime
dt_cols = ['PurchaseDt', 'nextLastPaymentDt', 'LastPaymentDt', 'LastPaymentEffectiveDate', 'DraftLastScheduledDt',
        'LoanModificationDt', 'acquisitiondt', 'mostrecentprokenpromisehistory', 'mostrecentcontact', 'NoteDt']

df[dt_cols] = df[dt_cols].apply(pd.to_datetime)

# %% [markdown]
# #### Remove Data with no UPB and no Purchase Date

# %%
# remove loans no upb
df = df.loc[df['upb']>1]

## remove loans that has no purchase date
df = df.dropna(axis=0, subset=['PurchaseDt'])

# %% [markdown]
# #### Date Treatments

# %%
## Date Treatments
df['rundt_day'] = df['rundt'].dt.day  
df['rundt_weekday'] = df['rundt'].dt.weekday
df['nextpaymentdue_day'] = df['nextpaymentduedt'].dt.day  
df['nextpayment_weekday'] = df['nextpaymentduedt'].dt.dayofweek

# get # of days in a month
df['days_in_month'] = df['nextpaymentduedt'].dt.daysinmonth

#get age
df['age'] = np.round((df['nextpaymentduedt'] - df['PurchaseDt'])/np.timedelta64(1, 'M'), 0).astype(int)

# %% [markdown]
# #### Numerical Features

# %% [markdown]
# ##### FICO

# %%
# Create a flag for FICO = 200 population
df['FICO_200'] = np.where(df['FICOScore']==200, 1,0)
df['FICOScore'] = np.where(df['FICOScore'].isnull(),0,df['FICOScore'])
df['FICO_flag'] = np.where(df['FICOScore']==0,1,0)

# %% [markdown]
# #### Mean Imputation

# %%
#cols = df.select_dtypes(np.floating).columns

cols = ['LTV', 'FrontDTI', 'borrowercount', 'TI','SSEC_Income','SEMP_Income', 'RNTL_Income',  
       'PNSN_Income', 'EMPL_Income','OTHR_Income' ]
impute = SimpleImputer(missing_values=np.nan,strategy='mean')
df[cols] = impute.fit_transform(df[cols])

# %% [markdown]
# #### Current LTV

# %%
#df['currentLTV']= df['upb']/df['Leadgen_Value']
#df['currentLTV'] = np.where(df['currentLTV'].isnull(), df['LTV'], df['currentLTV'])

# %% [markdown]
# ##### Income Percent

# %%
# income source convert to percentage 
df['EMPL_Income_per'] = df['EMPL_Income']/df['TI']
df['OTHR_Income_per'] = df['OTHR_Income']/df['TI']
df['PNSN_Income_per'] = df['PNSN_Income']/df['TI']
df['RNTL_Income_per'] = df['RNTL_Income']/df['TI']
df['SEMP_Income_per'] = df['SEMP_Income']/df['TI']
df['SSEC_Income_per'] = df['SSEC_Income']/df['TI']
df['OTHR_Income_per'] = df['OTHR_Income']/df['TI']

# %% [markdown]
# #### Payment Related

# %%
# payment info
df['current_total_pmt'] = df['currentescrowpayment'] + df['currentpipayment']
#df['LastPaymentAmt'] = np.where(df['LastPaymentAmt'].isnull, 0, df['LastPaymentAmt'])
df['upb_change']= df['upb'] -df['priorupb']
#df['pmt_diff'] = df['current_total_pmt'] - df['LastPaymentAmt']
#df['upb_minus_pmt_diff']= df['upb_change'] - df['pmt_diff']

# %% [markdown]
# #### Categorical Features

# %%
# Check missing data counts FOR OBJECT 
#cols = df.select_dtypes(np.object).columns
#df[cols].isna().mean().round(4)*100
# Out:
# loanstatusid                    0.00
# loanstatus                      0.00
# priorstatus                     0.58
# EscrowFlag                      0.00
# ForebearanceStatusCodeId       93.26
# InvestorId                      0.00
# DraftingIndicator              78.68
# InvestorName                    0.00
# status24months                  0.58
# CampaignProfile                 0.03
# COVIDforbearancetype           94.74
# producttype                     0.00
# selfemployed                   25.85
# DUtype                         24.08
# RealEstateOwnedCount           37.38
# LoanPurpose                     0.00
# fsttimehomebuyer                3.66
# amortizationtype                0.00
# doctype                        24.08
# PropState                       0.00
# zipcode                         0.00
# CBSACode                        0.00
# PropertyType                    0.00
# Occupancy                       0.00
# channel                         0.00
# HighBalanaceFlag                0.00
# Entity                          0.00
# tract_income_category          43.43
# application_income_category    43.43
# streamlineflag                  0.00
# apprbucket                      0.00
# amorttype                       0.00
# termbucket                      0.00
# CRAFlag                         0.00
# dtype: float64

# %% [markdown]
# #### Missing Imputation for Categorical

# %%
# using mode to impute missing categorical variables 
cols = ['fsttimehomebuyer']
impute = SimpleImputer(strategy="most_frequent") 
df[cols] = impute.fit_transform(df[cols])

# %% [markdown]
# #### Binary Flags (missing is more than 10%)

# %%
df['forebearance_status_flag']=np.where(df['ForebearanceStatusCodeId'].isnull(),0,1)
df['drafting_ind_flag']=np.where(df['DraftingIndicator'].isnull(),0,1)
df['Covid_flag']= np.where(df['COVIDforbearancetype'].isnull(), 0,1)
df['selfemployed_flag']= np.where(df['selfemployed'].isnull(), 0,1)
df['DUtype_flag']= np.where(df['DUtype'].isnull(), 0,1)
df['doctype_flag']= np.where(df['doctype'].isnull(), 0,1)
df['tract_income_category_flag']= np.where(df['tract_income_category'].isnull(), 0,1)
df['application_income_category_flag']= np.where(df['application_income_category'].isnull(), 0,1)


#extra
df['mod_flag'] = np.where(df['LoanModificationDt'].isnull(),0,1)
df['draft_flag']=np.where(df['DraftingIndicator'].isnull(),0,1)
df['ACHPmtSet_flag']= np.where(df['ACHPmtSet'].isnull(), 0,1)

# %% [markdown]
# #### RE Owned Count (RE owned count is mixed type)

# %%
#fill_na_mean(df['RealEstateOwnedCount'])
df['RealEstateOwnedCount'] = pd.to_numeric(df['RealEstateOwnedCount'], errors='coerce')
df['RealEstateOwnedCount'] = df['RealEstateOwnedCount'].fillna(value=df['RealEstateOwnedCount'].mean())

# %% [markdown]
# #### Lagged Variables

# %%
df['loanstatusid_lag1'] = df.groupby(['loanid','nextpaymentduedt'])['loanstatusid'].shift(1)
df['loanstatusid_lag1']= df['loanstatusid_lag1'].fillna(method='bfill') 

# create lagged payment variables 
df['lag1_PI'] = df.groupby(['loanid'])['currentpipayment'].shift(1)
df['lag1_Escrow'] = df.groupby(['loanid'])['currentescrowpayment'].shift(1)
df['lag1_total_pmt'] = df.groupby(['loanid'])['current_total_pmt'].shift(1)

#fill previous values 
df['lag1_PI']= df['lag1_PI'].fillna(method='bfill') 
df['lag1_Escrow']= df['lag1_Escrow'].fillna(method='bfill') 
df['lag1_total_pmt'] =df['lag1_total_pmt'].fillna(method='bfill') 

df['TI_change'] = df['current_total_pmt'] - df['lag1_total_pmt'] 
df['PI_change'] = df['currentpipayment'] - df['lag1_PI'] 
df['Escrow_change'] = df['currentescrowpayment'] - df['lag1_Escrow']

# %% [markdown]
# #### Avg Payment Days

# %%
avg_payment_day('AvgPmtDay_3M')
avg_payment_day('AvgPmtDay_6M')
avg_payment_day('AvgPmtDay_12M')

# %% [markdown]
# #### Streamline

# %%
df['streamline_flag']= np.where(df['streamlineflag']=='SL',1,0)

# %% [markdown]
# #### Check Missing %

# %%
#df.isna().mean().round(4)*100

# %% [markdown]
# #### Outlier Treatments

# %%
##

# %% [markdown]
# #### Export Processed data back to S-3

# %%
# %%time
import awswrangler as wr
wr.s3.to_parquet(
    df=df,
    path='s3://ppsg-collections/2021-06-01/consolidated/random_data/consolidated_sample_expanded_treated_v1.parquet'
)
# Out:
# CPU times: user 2min 57s, sys: 32.2 s, total: 3min 30s
# Wall time: 3min 6s
# {'paths': ['s3://ppsg-collections/2021-06-01/consolidated/random_data/consolidated_sample_expanded_treated_cltv.parquet'],
#  'partitions_values': {}}

# %%
#check_missing = df.isna().mean().round(4)*100
#check_missing.sort_values()

# %% [markdown]
# #### Check Good and Bad Counts

# %%
# def create_good_bad_table(df):
#     table= pd.crosstab(index=df['PastDue'], columns=[df['Down2']]).reset_index()
#     table= table.rename(columns={0: "G", 1: "B"})
#     table['percent'] = table['B']/( table['G']+ table['B'])*100
#     return table

# %%
# score = df[(df["CampaignProfile"]== "Never Delinquent") & (df["rollback"]== 0) 
#            & ((df["nextpaymentduedt"] >='2020-02-01') & (df["nextpaymentduedt"] <='2021-04-01'))]
# create_good_bad_table(score)
# Out:
# Down2  PastDue        G      B     percent
# 0            1  2338954  35447    1.492882
# 1            2  2109763  35441    1.652104
# 2            3  1933601  35442    1.799961
# 3            4  1768863  35442    1.964302
# 4            5  1541965  35443    2.246914
# 5            6  1422695  35443    2.430703
# 6            7  1320170  35443    2.614537
# 7            8  1215360  35443    2.833620
# 8            9  1117327  35443    3.074594
# 9           10   965049  35443    3.542557
# 10          11   871068  35443    3.909826
# 11          12   769654  35443    4.402327
# 12          13   668940  35443    5.031780
# 13          14   534893  35443    6.214407
# 14          15   313891  35443   10.145878
# 15          16   174248  35444   16.902886
# 16          17   143497  35444   19.807646
# 17          18   123392  35444   22.314840
# 18          19   107429  35444   24.808046
# 19          20    95140  35444   27.142682
# 20          21    83801  35444   29.723678
# 21          22    74367  35444   32.277276
# 22          23    66632  35444   34.723147
# 23          24    58578  35444   37.697560
# 24          25    51000  35444   41.002267
# 25          26    42427  35444   45.516303
# 26          27    34272  35444   50.840553
# 27          28    25417  35444   58.237623
# 28          29    16897  34902   67.379679
# 29          30     6963  34739   83.302959
# 30          31        0  33260  100.000000
# 31          32        0     20  100.000000
# 32          33        0     15  100.000000
# 33          34        0     13  100.000000
# 34          35        0     11  100.000000
# 35          36        0     10  100.000000
# 36          37        0      9  100.000000
# 37          38        0      9  100.000000
# 38          39        0      8  100.000000
# 39          40        0      5  100.000000
# 40          41        0      4  100.000000
# 41          42        0      4  100.000000
# 42          43        0      4  100.000000
# 43          44        0      4  100.000000
# 44          45        0      2  100.000000
# 45          46        0      2  100.000000
# 46          47        0      1  100.000000
# 47          48        0      1  100.000000

# %%
#df[(df['nextpaymentduedt']=='2020-08-01') & (df['loanid']==1000017603)][['rundt','PastDue']]
